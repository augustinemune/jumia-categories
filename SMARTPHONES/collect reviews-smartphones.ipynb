# %%
# !pip install requests requests_html bs4
# !pip install beautifulsoup4
# Out:
# Requirement already satisfied: requests in /srv/conda/envs/notebook/lib/python3.7/site-packages (2.23.0)
# Requirement already satisfied: requests_html in /srv/conda/envs/notebook/lib/python3.7/site-packages (0.10.0)
# Requirement already satisfied: bs4 in /srv/conda/envs/notebook/lib/python3.7/site-packages (0.0.1)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from requests) (1.25.9)
# Requirement already satisfied: idna<3,>=2.5 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from requests) (2.9)
# Requirement already satisfied: chardet<4,>=3.0.2 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from requests) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from requests) (2020.6.20)
# Requirement already satisfied: fake-useragent in /srv/conda/envs/notebook/lib/python3.7/site-packages (from requests_html) (0.1.11)
# Requirement already satisfied: pyquery in /srv/conda/envs/notebook/lib/python3.7/site-packages (from requests_html) (1.4.1)
# Requirement already satisfied: w3lib in /srv/conda/envs/notebook/lib/python3.7/site-packages (from requests_html) (1.22.0)
# Requirement already satisfied: pyppeteer>=0.0.14 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from requests_html) (0.2.2)
# Requirement already satisfied: parse in /srv/conda/envs/notebook/lib/python3.7/site-packages (from requests_html) (1.16.0)
# Requirement already satisfied: beautifulsoup4 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from bs4) (4.9.1)
# Requirement already satisfied: lxml>=2.1 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from pyquery->requests_html) (4.5.2)
# Requirement already satisfied: cssselect>0.7.9 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from pyquery->requests_html) (1.1.0)
# Requirement already satisfied: six>=1.4.1 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from w3lib->requests_html) (1.15.0)
# Requirement already satisfied: appdirs<2.0.0,>=1.4.3 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from pyppeteer>=0.0.14->requests_html) (1.4.4)
# Requirement already satisfied: tqdm<5.0.0,>=4.42.1 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from pyppeteer>=0.0.14->requests_html) (4.48.2)
# Requirement already satisfied: websockets<9.0,>=8.1 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from pyppeteer>=0.0.14->requests_html) (8.1)
# Requirement already satisfied: pyee<8.0.0,>=7.0.1 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from pyppeteer>=0.0.14->requests_html) (7.0.2)
# Requirement already satisfied: soupsieve>1.2 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from beautifulsoup4->bs4) (2.0.1)
# Requirement already satisfied: beautifulsoup4 in /srv/conda/envs/notebook/lib/python3.7/site-packages (4.9.1)
# Requirement already satisfied: soupsieve>1.2 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from beautifulsoup4) (2.0.1)

# %%
import requests
import requests_html
from requests_html import HTML

# %%
# urls = {
#     'https://www.jumia.co.ke/smart-tvs-2282/',
#     'https://www.jumia.co.ke/digital-tvs/',
#     'https://www.jumia.co.ke/led-lcd-tvs/',
#     'https://www.jumia.co.ke/complete-home-theater-systems/',
# }

# %%
url = "https://www.jumia.co.ke/smartphones/"

# %%
r = requests.get(url)
r.status_code
# Out:
# 200

# %%
r = requests.get(url)
r.status_code
# Out:
# 200

# %%
html_strg = r.text
html = HTML(html=html_strg)

# %%
from bs4 import BeautifulSoup

# %%
soup = BeautifulSoup(html_strg, 'html.parser')

# %%
all = soup.find_all(class_='_fb')
print(len(all))
# Out:
# 48

# %%
ff = soup.find_all(class_='_fb')
links = []
for article in ff:
    link = article.find(class_='core')['href']

    strf = f"https://www.jumia.co.ke{link}"
    links.append(strf)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-10-3dcdef2e763d> in <module>
#       2 links = []
#       3 for article in ff:
# ----> 4     link = article.find(class_='core')['href']
#       5
#       6     strf = f"https://www.jumia.co.ke{link}"
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/bs4/element.py in __getitem__(self, key)
#    1399         """tag[key] returns the value of the 'key' attribute for the Tag,
#    1400         and throws an exception if it's not there."""
# -> 1401         return self.attrs[key]
#    1402
#    1403     def __iter__(self):
#
# KeyError: 'href'

# %%
import pandas as pd

# %%
import pickle
datas = []
for item in links:
    individual = requests.get(item)
    html_sg = individual.text
    html = HTML(html=html_sg)

    soupp = BeautifulSoup(html_sg, 'html.parser')
    #print(soupp.prettify())
    ffreview = soupp.find_all(class_='cola')
    #print(len(ffreview))
    for tt in ffreview:
      no_reviews = tt.find(class_="-ptm")
      if no_reviews is not None:
        #print(no_reviews)
        rreview = no_reviews.string.replace('Product Reviews','')
        #print(rreview)
    for tt in ffreview:
      #author = tt.find(class_="-d-co")
      author = tt.find("p")
      if author != None:
        act = author.string
    print(rreview, act)
    data = {
        "Rating": rreview,
        "Review": act,
    }
    datas.append(data)
# Out:
#  (31) with the price i like it
#  (5) I love it. It met my expectations
#  (0) This product has no reviews yet.
#  (5) its cool what i had anticipated great work!
#  (2) Poor product
#  (45) My clients are saying it works perfectly
#  (0) This product has no reviews yet.
#  (3) Great gaming and  battery life
#  (1) Description are not correct. Change the description it may misguide the buyer.
#  (0) This product has no reviews yet.
#  (0) This product has no reviews yet.
#  (279) So far so good
#  (11) So far so good. Impressive functioning
#  (1) Been three days since I got it and I like it.
#  (42) The best specs....
#  (4) It meets my expectation for now, unless it develops a problem later.
#  (3) It is not clear whether it is 4G or not
#  (9) Improve on Camera
#  (21) Affordable
#  (8) gives me good power usage, but reprogrammes each night
#  (6) Poor quality
#  (238) Good phone on a budget
#  (3) It didnt meet my expectations. It has a different charger terminal rather than the common one for  android phones, even with the connector for headphones, its just additional items that one has to carry in order to use the phone.
# The hands free has low volume at its max. I haven't figured out to date how to expand the memory with a card.
# The camera is excellent!
#  (3) This product has no ratings yet.
#  (16) I wish that the official store has 6 gb version but even 4 gb is making sense.
#  (19) Very good
#  (19) This product has no ratings yet.
#  (1) Value for money
#  (1) battery drain very fast
#  (18) Jumia's return policy is a throw... don't be fooled by the 7-day return policy. This phone had issues with hanging, every time I could call someone the phone could hang or they could fail to hear me from the other end. I decided to take it back. The return policy is based on the quality management team that based my claims on a five minutes call that they say they used to invalidate my claims. So just because the phone didn't hang or disconnect during the five minutes call they made to assess the "quality" of the phone it makes my claim that the phone was hanging invalid. Yet, I had used that phone for two days and had issues with it hanging up and dropping. The google duo couldn't work too. I can't have bought a phone for 20K plus to just return it because of an invalid claim. This is too disappointing!!!!
#  (8) I bought this product following an outbid by Jumia through shake & win, which turned out to be a fake, suddenly hoping to recover 50% cash-back I rushed to acquire a smartphone and a tablet, at the end of it Jumia won, my wallet balance remained at 0 KES, suddenly, I stopped ordering on Jumia, but I continue to eat with FoodJumia
#  (8) ive been on  jumia at the time of the first infinix i bought from jumia mombasa when infinix was first on market
#  (34) Phone not accessing internet both on WiFi and data
#  (34) This product has no ratings yet.
#  (14) Battery its system is good
#  (0) This product has no reviews yet.
#  (123) Earphones
#  (7) Useless device with alot of bugs in the camera
#  (5) It's has an amazing camera and it's super fast
#  (1) Nokia c2 mobile  is good 4g phone.

# %%
df = pd.DataFrame(datas)
df.head()
# Out:
#   Rating                                       Review
# 0   (31)                     with the price i like it
# 1    (5)            I love it. It met my expectations
# 2    (0)             This product has no reviews yet.
# 3    (5)  its cool what i had anticipated great work!
# 4    (2)                                 Poor product

# %%
df.to_csv("smartphones.csv", index=False)
